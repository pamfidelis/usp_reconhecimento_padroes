# %% [markdown]
# # Dataset covid-19
#
# ## From: https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset?select=COVID19_open_line_list.csv

# %%
import pandas as pd

df = pd.read_csv("dataset/dataset_base_20200516.csv", low_memory=False)

# para mostrar toda a base
pd.set_option('display.max_columns', None)

df
# Out:
#         ID  age     sex                        city province country  \
# 0      1.0   30    male     Chaohu City, Hefei City    Anhui   China
# 1      2.0   47    male  Baohe District, Hefei City    Anhui   China
# 2      3.0   49    male  High-Tech Zone, Hefei City    Anhui   China
# 3      4.0   47  female  High-Tech Zone, Hefei City    Anhui   China
# 4      5.0   50  female  Feidong County, Hefei City    Anhui   China
# ...    ...  ...     ...                         ...      ...     ...
# 14121  NaN  NaN     NaN                         NaN      NaN     NaN
# 14122  NaN  NaN     NaN                         NaN      NaN     NaN
# 14123  NaN  NaN     NaN                         NaN      NaN     NaN
# 14124  NaN  NaN     NaN                         NaN      NaN     NaN
# 14125  NaN  NaN     NaN                         NaN      NaN     NaN
#
#        wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  \
# 0                        1.0  31.646960  117.716600         admin3
# ...

# %% [markdown]
# ### Tratamento básico

# %%
# remoção de campos desnecessários

df.drop(columns =[
    "wuhan(0)_not_wuhan(1)", 
    "geo_resolution", 
    "reported_market_exposure", 
    "additional_information",
    "source", 
    "sequence_available",
    "notes_for_discussion", 
    "location", 
    "admin3", 
    "admin2", 
    "data_moderator_initials", 
    "admin_id",
    "country_new", 
    "admin1",    
], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f1b11c600d8c> in <module>
#      16     "country_new",
#      17     "admin1",
# ---> 18 ], inplace = True)
#      19
#      20 df = df.dropna(axis=0, subset=['outcome'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df = df.dropna(axis=0, subset=['outcome'])

df
# Out:
#             ID  age     sex                                     city  \
# 18        19.0  NaN  female                          Daxing District
# 55        56.0   44  female                            Wushan County
# 161      164.0   29    male                       Fangchenggang City
# 175      178.0  NaN     NaN                              Suihua City
# 185      192.0   39    male                                Hong Kong
# ...        ...  ...     ...                                      ...
# 11736  12042.0  NaN     NaN                              Dingxi City
# 11737  12043.0   33  female            Yongdeng County, Lanzhou City
# 11740  12046.0   58  female  National Centre for Infectious Diseases
# 11800  12106.0   60    male                                    Paris
# 11801  12107.0  NaN  female                                      NaN
#
#             province      country   latitude   longitude date_onset_symptoms  \
# ...
